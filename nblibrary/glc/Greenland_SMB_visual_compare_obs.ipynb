# %% [markdown]
# # Greenland Ice Sheet SMB comparison with MAR
# This notebook compares the downscaled output of surface mass balance (SMB) over the Greenland ice sheet (GrIS) to the regional model MAR. In what follows, we interchangeably call the MAR data "observation".
# \
# Note1: the MAR data are processed as a climatology spanning 1960-1999.\
# Note2: the MAR data are available at a uniform resolution of 1km using the same projection as the CISM grid. This notebook requires the interpolation of the MAR data on the CISM grid. The interpolation is done in this notebook (for now) to allow for the eventuality of the CISM grid or the MAR grid to change in the future. \
# creation: 05-26-24 \
# contact: Gunter Leguy (gunterl@ucar.edu)

# %%
# Import packages
import os

import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import RegularGridInterpolator
import xarray as xr

from cupid_utils.glc import utils

# to display figures in notebook after executing the code.
# %matplotlib inline

# %% [markdown]
# ## Parameter configuration
#
# Some parameters are set in CUPiD's `config.yml` file,
# others are derived from these parameters.

# %%
# Parameter Defaults

CESM_output_dir = []
case_names = []
case_nicknames = []
start_dates = []
end_dates = []
climo_nyears = 0  # number of years to compute the climatology for main case

obs_data_dir = ""  # global directory containing observed dataset
obs_path = ""  # specific directory containing observed dataset
obs_name = ""  # file name for observed dataset

# %%
# Set up case parameters in dictionary

case_info = {}
for case_name, case_nickname, start_date, end_date, CESM_output_dir in zip(
    case_names, case_nicknames, start_dates, end_dates, CESM_output_dir
):
    last_year = int(
        end_date.split("-")[0]
    )  # in loop because we are going to make star_year & end_year a list in the config file to allow for different time periods for each case
    case_path = os.path.join(
        CESM_output_dir, case_name, "cpl", "hist"
    )  # name of glc file output
    case_file = os.path.join(
        case_path, f"{case_name}.cpl.hx.1yr2glc.{last_year:04d}-01-01-00000.nc"
    )  # name of glc file output

    case_info[case_name] = {
        "case_nickname": case_nickname,
        "start_date": start_date,
        "end_date": end_date,
        "case_path": case_path,
        "case_file": case_file,
        "last_year": last_year,
    }

case_init_file = os.path.join(
    obs_data_dir,
    obs_path,
    "greenland_4km_epsg3413_c251001.nc",  # "cism.gris.initial_hist.0001-01-01-00000.nc",  # "greenland_4km_epsg3413_c251001.nc"
)  # name of glc file output

obs_file = os.path.join(
    obs_data_dir, obs_path, obs_name
)  # name of observed dataset file

# %% [markdown]
# ## Set up grid
#
# Read in the grid data, compute resolution and other grid-specific parameters

# %%
## Get grid from initial_hist stream
thk_init_da = xr.open_dataset(case_init_file).isel(time=0)["thk"]
mask = thk_init_da.data[:, :] == 0

# Shape of array is (ny, nx)
grid_dims = thk_init_da.shape

# %%
# Constants
res = np.abs(
    thk_init_da["x1"].data[1] - thk_init_da["x1"].data[0]
)  # CISM output resolution

rhow = 1000  # water density kg/m3
kg_to_Gt = 1e-12  # Converting kg to Gt
mm_to_Gt = rhow * 1e-3 * res**2 * kg_to_Gt  # converting mm/yr to Gt/yr

# %%
params = {
    "grid_dims": grid_dims,
    "mm_to_Gt": mm_to_Gt,
    "mask": mask,
}

# %% [markdown]
# ## Make datasets
#
# Read in observations and CESM output.
# Also do necessary computations
# (global mean for time series, temporal mean for climatology).

# %%
# creating the SMB climatology for new case

for case_name, case_data in case_info.items():
    smb_case = utils.read_cesm_smb(
        case_data["case_path"], case_name, case_data["last_year"], climo_nyears, params
    )
    smb_case_climo = smb_case.mean("time")

    case_info[case_name]["smb_case"] = smb_case
    case_info[case_name]["smb_case_climo"] = smb_case_climo

# %%
# Interpolating the observed data onto the CISM grid
smb_obs_da = xr.open_dataset(obs_file).isel(time=0)["SMB"]

# Defining the interpolation functions
myInterpFunction_smb_obs = RegularGridInterpolator(
    (smb_obs_da["x"].data, smb_obs_da["y"].data),
    smb_obs_da.data.transpose(),
    method="linear",
    bounds_error=False,
    fill_value=None,
)

# Initializing the glacier ID variable
smb_obs_climo = xr.DataArray(np.zeros(grid_dims), dims=["glc1Exp_ny", "glc1Exp_nx"])

# Performing the interpolation
for j in range(grid_dims[0]):
    point_y = np.zeros(grid_dims[1])
    point_y[:] = thk_init_da["y1"].data[j]
    pts = (thk_init_da["x1"].data[:], point_y[:])
    smb_obs_climo.data[j, :] = myInterpFunction_smb_obs(pts)

# Filtering out fill values
smb_obs_climo.data = np.where(
    np.logical_or(mask, smb_obs_climo > 1e20), 0, smb_obs_climo
)

# %%
# Integrated SMB time series

for case_name, case_data in case_info.items():
    smb_case = case_data["smb_case"]
    first_year = case_data["last_year"] - len(smb_case["time"]) + 1
    avg_smb_case_climo = smb_case.sum(["glc1Exp_ny", "glc1Exp_nx"]) * params["mm_to_Gt"]

    case_info[case_name]["avg_smb_case_climo"] = avg_smb_case_climo
    case_info[case_name]["first_year"] = first_year

# %% [markdown]
# ## Generate plots
#
# Map comparing CESM to observation,
# possibly map comparing CESM to older case,
# and time series of spatial mean SMB.

# %%
# Comparing SMB new run vs obs

# Colormap choice
my_cmap = plt.get_cmap("Spectral")
my_cmap_diff = plt.get_cmap("bwr_r")


# Colorbar bounds
vmin = -2000
vmax = 2000

# Figure
n_cases = len(case_names)

fig, ax = plt.subplots(
    2,
    n_cases + 1,
    sharey=True,
    figsize=[22, 16],
    squeeze=False,
)

# --- top row, first column: obs ---
utils.plot_contour(
    smb_obs_climo,
    fig,
    ax[0, 0],
    0.35,
    "SMB Obs\n(mm/y w.e.)",
    vmin,
    vmax,
    my_cmap,
    mm_to_Gt,
)

for i, (case_name, case_data) in enumerate(case_info.items()):
    smb_case_climo = case_data["smb_case_climo"]
    first_year = case_data["first_year"]
    last_year = case_data["last_year"]

    # Next panels
    utils.plot_contour(
        smb_case_climo,
        fig,
        ax[0, i + 1],
        0.95,
        f"{case_data["case_nickname"]}\nSMB (mm/y w.e.)\nMean from {first_year:04d} - {last_year:04d}",
        vmin,
        vmax,
        my_cmap,
        mm_to_Gt,
    )

# remove extra colormap
for a in fig.axes[ax.size : -1]:
    a.remove()

# --- bottom row, first column: blank ---
ax[1, 0].axis("off")

for i, (case_name, case_data) in enumerate(case_info.items()):
    smb_case_climo = case_data["smb_case_climo"]
    first_year = case_data["first_year"]
    last_year = case_data["last_year"]

    # --- remaining columns: case SMB on top, case-obs bias on bottom ---
    utils.plot_contour(
        smb_case_climo - smb_obs_climo,
        fig,
        ax[1, i + 1],
        0.95,
        f"\nSMB bias (mm/yr w.e.)\n{case_data['case_nickname']} - SMB Obs",
        vmin,
        vmax,
        my_cmap_diff,
        mm_to_Gt,
    )

# %%
# Comparing SMB new run vs base case

# use case_name[0] as base case
base_case_name = case_names[0]
base_case_data = case_info[base_case_name]

if len(case_names) > 1:
    # Colormap choice
    my_cmap = plt.get_cmap("Spectral")
    my_cmap_diff = plt.get_cmap("bwr_r")

    # Colorbar bounds
    vmin = -2000
    vmax = 2000

    # compare cases against base case
    base_smb_case_climo = base_case_data["smb_case_climo"]
    base_nickname = base_case_data["case_nickname"]
    base_first_year = base_case_data["first_year"]
    base_last_year = base_case_data["last_year"]

    n_plot_cases = len(case_names)

    fig, ax = plt.subplots(
        2,
        n_plot_cases,
        sharey=True,
        figsize=[22, 16],
        squeeze=False,
    )

    # --- top row, first column: base case ---
    utils.plot_contour(
        base_smb_case_climo,
        fig,
        ax[0, 0],
        0.92,
        f"{base_nickname}\nSMB (mm/y w.e.)\nMean from {base_first_year:04d} - {base_last_year:04d}",
        vmin,
        vmax,
        my_cmap,
        mm_to_Gt,
    )

    # --- bottom row, first column: blank ---
    ax[1, 0].axis("off")

    # --- remaining columns: case SMB on top, case-base bias on bottom ---
    for i, case_name in enumerate(case_names[1:], start=1):
        case_data = case_info[case_name]
        smb_case_climo = case_data["smb_case_climo"]

        # top row
        utils.plot_contour(
            smb_case_climo,
            fig,
            ax[0, i],
            0.92,
            f"{case_data["case_nickname"]}\nSMB (mm/y w.e.)\nMean from {case_data["first_year"]:04d} - {case_data["last_year"]:04d}",
            vmin,
            vmax,
            my_cmap,
            mm_to_Gt,
        )

        # bottom row
        utils.plot_contour(
            smb_case_climo - base_smb_case_climo,
            fig,
            ax[1, i],
            0.92,
            f"SMB bias (mm/yr w.e.)\n{case_data["case_nickname"]} - {base_nickname}",
            vmin,
            vmax,
            my_cmap_diff,
            mm_to_Gt,
        )

# %%
# Plotting the SMB spatially averaged time series

# TODO: include base case, base case climo (horizontal line), new case, new case climo, and obs climo
# Note: base case is 10 years of historical, new case is PI.
#       what comparisons make sense when base case is HIST and new case is 1850?

base_first_year = base_case_data["first_year"]
base_last_year = base_case_data["last_year"]
base_time = np.arange(base_first_year, base_last_year + 1)
base_nt = len(base_time)

for i, case_name in enumerate(case_names):
    case_data = case_info[case_name]

    if i == 0:
        time = np.arange(case_data["first_year"], case_data["last_year"] + 1)
        full_time = time
        nt = len(time)
    else:
        time = (
            np.arange(case_data["first_year"], case_data["last_year"] + 1)
            + base_first_year
            - case_data["first_year"]
        )
        full_time = np.arange(base_time[0], max(base_time[-1], time[-1]) + 1)
        nt = len(time)

    case_data["time"] = time
    case_data["full_time"] = full_time
    case_data["nt"] = nt


for case_name, case_data in case_info.items():
    smb_case_climo = case_data["smb_case_climo"]
    nt = case_data["nt"]

    avg_smb_case_timeseries = np.zeros(nt)
    avg_smb_case_timeseries[:] = np.round(smb_case_climo.sum() * mm_to_Gt, 2)

    case_data["avg_smb_case_timeseries"] = avg_smb_case_timeseries


min_year = min(case["time"][0] for case in case_info.values())
max_year = max(case["time"][-1] for case in case_info.values())

full_time_all = np.arange(min_year, max_year + 1)

avg_smb_obs_timeseries = np.zeros(len(full_time_all))
avg_smb_obs_timeseries[:] = np.round(smb_obs_climo.sum() * mm_to_Gt, 2)

x_ticks = np.arange(full_time_all[0], full_time_all[-1] + 2, 5)

ymin = 100
ymax = 600
y_step = 50

plt.figure(figsize=(16, 7))

# Plotting annual / spatial means
plt.subplot(111)

# cmap = plt.get_cmap("tab10")
# colors = cmap(np.linspace(0, 1, len(case_names)))
cmap = plt.get_cmap("Set1")
colors = cmap.colors[: len(case_names)]

for i, case_name in enumerate(case_names):
    color = colors[i]
    case_data = case_info[case_name]
    avg_smb_case_climo = case_data["avg_smb_case_climo"]
    avg_smb_case_timeseries = case_data["avg_smb_case_timeseries"]
    time = case_data["time"]

    utils.plot_line(
        avg_smb_case_climo,
        time,
        line="-",
        color=color,
        label=f"{case_data["case_nickname"]} ({case_data["first_year"]:04d} - {case_data["last_year"]:04d})",
        linewidth=2,
    )
    utils.plot_line(
        avg_smb_case_timeseries[:],
        time,
        line=":",
        color=color,
        label=f"{case_data["case_nickname"]} (mean from {case_data["first_year"]:04d} - {case_data["last_year"]:04d})",
        linewidth=2,
    )

utils.plot_line(
    avg_smb_obs_timeseries,
    full_time_all,
    line="-",
    color="black",
    label="Observations (mean)",
    linewidth=2,
)


sizefont = 16
plt.xlim([min_year, max_year])
plt.xticks(x_ticks, x_ticks, fontsize=sizefont)
plt.xlabel(r"$Time$ (y)", fontsize=sizefont)
plt.ylabel("SMB average evolution (Gt/yr)", multialignment="center", fontsize=sizefont)
plt.ylim([ymin, ymax])
plt.yticks(fontsize=sizefont)
plt.legend(loc="upper left", ncol=1, frameon=True, borderaxespad=0)

plt.title("SMB average evolution", fontsize=sizefont);
